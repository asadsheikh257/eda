# %%
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv('Zomatodataset/zomato.csv', encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## In Data Analysis What All Things We Do
# 1. Handling Missing values
# 2. Explore about the Numerical Variables
# 3. Explore about the Categorical Variables
# 4. Find Relationship between features

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cuisines                9
# Restaurant ID           0
# Currency                0
# Rating text             0
# Rating color            0
# Aggregate rating        0
# Price range             0
# Switch to order menu    0
# Is delivering now       0
# Has Online delivery     0
# Has Table booking       0
# Average Cost for two    0
# Restaurant Name         0
# Latitude                0
# Longitude               0
# Locality Verbose        0
# Locality                0
# Address                 0
# City                    0
# Country Code            0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum() >= 1]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(), cmap='viridis', yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
df_country = pd.read_excel('Zomatodataset/Country-Code.xlsx')

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
final_df = pd.merge(df, df_country, on='Country Code', how='right')

# %%
final_df.head(2)
# Out:
#    Restaurant ID      Restaurant Name  Country Code  City  \
# 0        3400025           Jahanpanah             1  Agra
# 1        3400341  Rangrezz Restaurant             1  Agra
#
#                                              Address    Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
#
#    Locality Verbose  Longitude   Latitude               Cuisines  ...  \
# 0  Agra Cantt, Agra  78.011544  27.161661  North Indian, Mughlai  ...
# 1  Agra Cantt, Agra   0.000000   0.000000  North Indian, Mughlai  ...
#
#    Has Table booking Has Online delivery Is delivering now  \
# 0                 No                  No                No
# 1                 No                  No                No
#
#   Switch to order menu Price range Aggregate rating  Rating color  \
# 0                   No           3              3.9        Yellow
# ...

# %%
# to check data type 
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_names = final_df.Country.value_counts().index

# %%
country_val = final_df.Country.value_counts().values

# %%
# Pie Chart 
plt.pie(country_val[:3], labels=country_names[:3], autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Observation: Maximum numbers of records are from India and USA after then UK.

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ### Observation:
# 1. Rating between 4.5 to 4.9 ----> Excellent
# 2. Rating between 4.0 to 4.4 ----> Very Good
# 3. Rating between 3.5 to 3.9 ----> Good
# 4. Rating between 2.5 to 3.4 ----> Average
# 5. Rating between 1.8 to 2.4 ----> Poor
# 6. Rating is equal to 0.0 Means not rated

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='Aggregate rating', y='Rating Count', data=ratings)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(x='Aggregate rating', y='Rating Count', hue='Rating color', data=ratings)
plt.show()

# %%
color = ['black','red','orange','yellow','green','green']
plt.figure(figsize=(16,8))
sns.barplot(x='Aggregate rating', y='Rating Count', hue='Rating color', data=ratings, palette=color)
plt.show()

# %% [markdown]
# ### Observation:
# 1. Not Rated `Black` is very High
# 2. Maximum number of Ratings are between 2.6 to 4.3

# %%
# countplot 
sns.countplot(x='Rating color', data=ratings, palette=color)
plt.show()
# Out:
# C:\Users\Asad\AppData\Local\Temp\ipykernel_6588\665435552.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color', data=ratings, palette=color)

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Find the countries names with 0 rating?

final_df[final_df['Aggregate rating'] == 0.0]['Country'].unique()
# Out:
# array(['India', 'Brazil', 'United Kingdom', 'United States'], dtype=object)

# %%
# Find out which currency is being used by country name?

final_df[['Country', 'Currency']].drop_duplicates()
# Out:
#              Country                Currency
# 0              India      Indian Rupees(Rs.)
# 8652       Australia               Dollar($)
# 8676          Brazil      Brazilian Real(R$)
# 8736          Canada               Dollar($)
# 8740       Indonesia  Indonesian Rupiah(IDR)
# 8761     New Zealand           NewZealand($)
# 8801     Phillipines        Botswana Pula(P)
# 8823           Qatar         Qatari Rial(QR)
# 8843       Singapore               Dollar($)
# 8863    South Africa                 Rand(R)
# 8923       Sri Lanka   Sri Lankan Rupee(LKR)
# 8943          Turkey        Turkish Lira(TL)
# 8977             UAE      Emirati Diram(AED)
# 9037  United Kingdom              Pounds(£)
# 9117   United States               Dollar($)

# %%
# Which countries do have online deliveries?

final_df[['Country', 'Has Online delivery']].groupby(['Country', 'Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %% [markdown]
# ### Observation: Online Deliveries are available only in India and UAE

# %%
# Top 5 city distribution?

city_val = final_df.City.value_counts().values
city_nam = final_df.City.value_counts().index

plt.pie(city_val[:5], labels=city_nam[:5], autopct='%.1f%%')
plt.show()

# %%
# Find top 10 Cuisines?

top_cuisines = final_df['Cuisines'].value_counts().reset_index()
top_cuisines.head(10)
# Out:
#                          Cuisines  count
# 0                    North Indian    936
# 1           North Indian, Chinese    511
# 2                       Fast Food    354
# 3                         Chinese    354
# 4           North Indian, Mughlai    334
# 5                            Cafe    299
# 6                          Bakery    218
# 7  North Indian, Mughlai, Chinese    197
# 8                Bakery, Desserts    170
# 9                     Street Food    149
